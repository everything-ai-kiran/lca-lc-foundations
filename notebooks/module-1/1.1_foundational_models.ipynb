# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon isn’t a country and has no government, so it has no capital. If you’re curious, I can share how future lunar bases or colonies might be organized.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 561, 'prompt_tokens': 13, 'total_tokens': 574, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DR3RX4ZFLinucAXZVbio752bNyBDv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d5a89-9f76-7a12-9334-ced4da1e1233-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 561, 'total_tokens': 574, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government, so it has no capital. If you’re curious, I can share how future lunar bases or colonies might be organized.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-DR3RX4ZFLinucAXZVbio752bNyBDv',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 561,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 512,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 574}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government or capital city. If you were asking as a joke, the “capital” of Moon is the letter M. If you want real info, I can share about lunar exploration or plans for future bases.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[8], line 3
#       1 model = init_chat_model(model="claude-sonnet-4-5")
# ----> 3 response = model.invoke("What's the capital of the Moon?")
#       4 print(response.content)
#
# File ~/Code/Repos/everything-ai-kiran/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:454, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     440 @override
#     441 def invoke(
#     442     self,
#    (...)    447     **kwargs: Any,
#     448 ) -> AIMessage:
#     449     config = ensure_config(config)
#     450     return cast(
#     451         "AIMessage",
#     452         cast(
#     453             "ChatGeneration",
# --> 454             self.generate_prompt(
#     455                 [self._convert_input(input)],
#     456                 stop=stop,
#     457                 callbacks=config.get("callbacks"),
#     458                 tags=config.get("tags"),
#     459                 metadata=config.get("metadata"),
#     460                 run_name=config.get("run_name"),
#     461                 run_id=config.pop("run_id", None),
#     462                 **kwargs,
#     463             ).generations[0][0],
#     464         ).message,
#     465     )
#
# File ~/Code/Repos/everything-ai-kiran/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1201, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1192 @override
#    1193 def generate_prompt(
#    1194     self,
#    (...)   1198     **kwargs: Any,
#    1199 ) -> LLMResult:
#    1200     prompt_messages = [p.to_messages() for p in prompts]
# -> 1201     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Code/Repos/everything-ai-kiran/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1010, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1007 for i, m in enumerate(input_messages):
#    1008     try:
#    1009         results.append(
# -> 1010             self._generate_with_cache(
#    1011                 m,
#    1012                 stop=stop,
#    1013                 run_manager=run_managers[i] if run_managers else None,
#    1014                 **kwargs,
#    1015             )
#    1016         )
#    1017     except BaseException as e:
#    1018         if run_managers:
#
# File ~/Code/Repos/everything-ai-kiran/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1313, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1311     result = generate_from_stream(iter(chunks))
#    1312 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1313     result = self._generate(
#    1314         messages, stop=stop, run_manager=run_manager, **kwargs
#    1315     )
#    1316 else:
#    1317     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Code/Repos/everything-ai-kiran/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_anthropic/chat_models.py:1434, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1432     data = self._create(payload)
#    1433 except anthropic.BadRequestError as e:
# -> 1434     _handle_anthropic_bad_request(e)
#    1435 return self._format_output(data, **kwargs)
#
# File ~/Code/Repos/everything-ai-kiran/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_anthropic/chat_models.py:1432, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1430 payload = self._get_request_payload(messages, stop=stop, **kwargs)
#    1431 try:
# -> 1432     data = self._create(payload)
#    1433 except anthropic.BadRequestError as e:
#    1434     _handle_anthropic_bad_request(e)
#
# File ~/Code/Repos/everything-ai-kiran/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_anthropic/chat_models.py:1286, in ChatAnthropic._create(self, payload)
#    1284 if "betas" in payload:
#    1285     return self._client.beta.messages.create(**payload)
# -> 1286 return self._client.messages.create(**payload)
#
# File ~/Code/Repos/everything-ai-kiran/lca-lc-foundations/.venv/lib/python3.12/site-packages/anthropic/_utils/_utils.py:282, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     280             msg = f"Missing required argument: {quote(missing[0])}"
#     281     raise TypeError(msg)
# --> 282 return func(*args, **kwargs)
#
# File ~/Code/Repos/everything-ai-kiran/lca-lc-foundations/.venv/lib/python3.12/site-packages/anthropic/resources/messages/messages.py:996, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     989 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#     990     warnings.warn(
#     991         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#     992         UserWarning,
#     993         stacklevel=3,
#     994     )
# --> 996 return self._post(
#     997     "/v1/messages",
#     998     body=maybe_transform(
#     999         {
#    1000             "max_tokens": max_tokens,
#    1001             "messages": messages,
#    1002             "model": model,
#    1003             "cache_control": cache_control,
#    1004             "container": container,
#    1005             "inference_geo": inference_geo,
#    1006             "metadata": metadata,
#    1007             "output_config": output_config,
#    1008             "service_tier": service_tier,
#    1009             "stop_sequences": stop_sequences,
#    1010             "stream": stream,
#    1011             "system": system,
#    1012             "temperature": temperature,
#    1013             "thinking": thinking,
#    1014             "tool_choice": tool_choice,
#    1015             "tools": tools,
#    1016             "top_k": top_k,
#    1017             "top_p": top_p,
#    1018         },
#    1019         message_create_params.MessageCreateParamsStreaming
#    1020         if stream
#    1021         else message_create_params.MessageCreateParamsNonStreaming,
#    1022     ),
#    1023     options=make_request_options(
#    1024         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1025     ),
#    1026     cast_to=Message,
#    1027     stream=stream or False,
#    1028     stream_cls=Stream[RawMessageStreamEvent],
#    1029 )
#
# File ~/Code/Repos/everything-ai-kiran/lca-lc-foundations/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1364, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1355     warnings.warn(
#    1356         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1357         "Please pass raw bytes via the `content` parameter instead.",
#    1358         DeprecationWarning,
#    1359         stacklevel=2,
#    1360     )
#    1361 opts = FinalRequestOptions.construct(
#    1362     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1363 )
# -> 1364 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Code/Repos/everything-ai-kiran/lca-lc-foundations/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1137, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1134             err.response.read()
#    1136         log.debug("Re-raising status error")
# -> 1137         raise self._make_status_error_from_response(err.response) from None
#    1139     break
#    1141 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'Your credit balance is too low to access the Anthropic API. Please go to Plans & Billing to upgrade or purchase credits.'}, 'request_id': 'req_011CZjVdFz899rsUrykjyCzy'}

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# That's a fun question! The Moon doesn't have a capital city, or any cities at all for that matter. It's a natural celestial body, not a country or political entity.
#
# So, the answer is: **The Moon has no capital.**

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='cc6b3b5c-4207-49cb-88e2-41f87b917394'),
#               AIMessage(content="There isn't one. The Moon isn’t a country or government, so it has no capital or seat of government. In science fiction people sometimes imagine a capital city on the Moon, but in reality no such place exists.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 437, 'prompt_tokens': 13, 'total_tokens': 450, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DR3U4CTp9IBEIJG6Xzfir0LL7GVtU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d5a8c-076a-7503-9a6a-85bff997174b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 437, 'total_tokens': 450, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn't one. The Moon isn’t a country or government, so it has no capital or seat of government. In science fiction people sometimes imagine a capital city on the Moon, but in reality no such place exists.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='2906a1fc-bb3b-4d60-9a4a-cb67db7da110'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='3450640d-c9ea-491f-b5f2-21b507c3d9ec', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='d5c3f172-8911-4a1d-8da1-6483924416fb'),
#               AIMessage(content='Luna City is a fictional concept, not a real place. Here’s a detailed, story-friendly profile you can use for world-building, a game, or a novel.\n\nOverview\n- Location: Built along the rim of Shackleton Crater near the Moon’s south pole, where sunlit ridges meet shadowed floors. The site gives long solar exposure for power and access to permanent-ice reservoirs a short distance away.\n- Purpose: A political and economic capital of the Moon, focused on research, mining, manufacturing, and culture. It’s home to the Lunar Commonwealth’s seat of government and the busiest hub for Earth–Luna transit.\n- Population: Roughly 350,000 residents, including scientists, engineers, miners, farmers in controlled greenhouses, and a vibrant civilian population with families, artists, and entrepreneurs.\n\nLayout and districts\n- Core District: The political and ceremonial heart, housing the City Hall, the Lunar Assembly, the Chief Archivist’s vault, and the grand plaza known as the Moonrise Forum.\n- Residential Ring: Interconnected neighborhoods in shielded domes and underground habitats, with parks, schools, clinics, and community centers.\n- Industrial Belt: ISRU facilities, mining support, 3D-printing yards, and processing plants for refined metals, oxygen, and water extraction.\n- Shadow and Ice Zones: Access tunnels and underground caverns linked to near-surface ice deposits. Permanent shade pockets are used for cooling and storage.\n- Transit Spine: A ring rail around the crater rim with elevated, pressurized trams and autonomous freighters that shuttle between districts and orbital ports.\n\nInfrastructure and living\n- Energy and power: A large solar farm on the sunlit rim plus energy storage in basaltic domes. Redundant microgrids keep hospitals and greenhouses running during dust storms.\n- Water and life support: ISRU units harvest water ice from shadowed craters, then electrolyze it for oxygen and life-support needs. Greenhouses use recycled water and controlled atmosphere farming.\n- Housing: 3D-printed and modular habitats with radiation shielding, insulation, and biodepth cooling. Many homes have gravity-adjusted floors to simulate Earth-like movement for long-term health.\n- Transportation: Surface maglev-like shuttles, pressurized transit tubes, and EVA corridors. Personal mobility is via light-weight rovers and foot-holds inside protected pedestrian tunnels.\n\nEconomy\n- Core industries: Helium-3 and rare-earth material mining, water ice mining, oxygen production, 3D-printed components, and high-precision optics manufacturing.\n- Research and tech: Lunar laboratories for astronomy, materials science, life-support tech, and regenerative medicine using microgravity experiments.\n- Culture and services: Education hubs, museums, theaters, and digital markets linking Earth and lunar residents.\n\nGovernance and society\n- Government: The Lunar Commonwealth oversees Luna City, with a City Council elected by residents and a ceremonial Governor representing Earth-Luna relations. A professional civil service runs day-to-day operations.\n- Law and order: Community councils in each district handle local issues, with a lunar-justice court for disputes and a small security force focused on EVA safety, disaster response, and infrastructure protection.\n- Society and culture: A melting pot of Earth cultures, with strong emphasis on scientific literacy, environmental stewardship, and a shared lunar identity. Seasonal festivals celebrate solar alignments, water-ice discoveries, and long-term spaceflight milestones.\n\nTechnology and science\n- Architecture: Radiation shielding integrated into every building; exterior walls use regolith composites and water-ice frost to stabilize temperatures.\n- Medical: On-site clinics with regenerative medicine labs, telemedicine links to Earth hospitals, and research into long-duration space health.\n- Astronomy: An observatory complex on a sun-facing terrace with tele ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# There isn’t a real Luna City that serves as the capital of the Moon. If you’re asking for a fictional setting, here’s a thorough worldbuilding concept you can use as a base for stories, games, or a game master’s guide. It covers geography, government, society, technology, economy, culture, and everyday life.
#
# Core concept
# - Luna City is the political and cultural capital of a semi-autonomous lunar federation. It sits inside a large crater near the Moon’s southern pole, where water ice is recoverable and permanent shadow and near-constant sunlight can be managed with clever engineering. The city is a flagship of human settlement on the Moon, a hub for science, industry, diplomacy with Earth, and lunar identity.
#
# Location and environment
# - Location: A permanently shadowed floor of a polar crater with a rim that receives near-constant sunlight for most of the lunar day. The ice at the crater floor supplies water, oxygen, and potential hydrogen for fuel. The city is protected by multiple shielding layers and a near-vacuum climate that must be maintained inside every habitat.
# - Climate challenges: Extreme temperature swings, micrometeoroid debris, and lunar dust (regolith) that cling to surfaces and compact into machinery. Radiation is a constant hazard, mitigated by thick regolith shielding, water-ice barriers, and localized magnetic/architectural shielding.
# - Architecture concept: A network of pressurized domes, lava-tube tunnels, and ringed arcologies connected by radiation-shielded transit corridors. Exterior surfaces are covered with high-efficiency solar arrays and regolith shielding; inside, gravity is 1/6 that of Earth, so spaces are designed for low-gravity movement and bone/muscle health.
#
# Government and politics
# - Political structure: The Lunar Commonwealth (or Lunar Federation) governs Moon-wide matters in conjunction with Earth-based authorities. Luna City houses the seat of the Lunar Council, the executive branch, and the supreme lunar court.
# - Leadership: A Prime Commissioner (or President of the Lunar Council) presides over the city, with a rotating cabinet drawn from districts. The Lunar Assembly represents regional interests within the city’s districts.
# - Legal framework: A lunar constitution guarantees resource rights, orbital commerce access, astronaut labor protections, and a codified “Moon-time” law to coordinate with Earth-timekeeping. There’s a formal electoral cycle for district representatives and a civilian oversight committee for AI and infrastructure.
#
# Geography and urban layout
# - Core districts (arranged in concentric rings around an inland heart):
#   1) The Core Ring (administration and core services): governorship offices, archives, the council chambers, and the main data center.
#   2) The Nexus District (science and technology): research labs, AI governance center, robotics incubators, and the meteorology/geoengineering hub.
#   3) The Helios Arcology (energy and industry): power generation, cryogenic processing, manufacturing, and metalworks.
#   4) The Icewell Quarter (water, life support, agriculture): ice mining facilities, water processing, hydroponic farms, and food manufacturing.
#   5) The Crater Rim Heights (residential): mixed-density housing, schools, clinics, and community centers with views of the crater floor.
#   6) The Aurora Cultural District (arts, education, and tourism): museums, theaters, galleries, universities, and cultural centers.
#   7) The Vaults (archives and diplomacy): historic lunar data, Earth-Lunar treaty archives, and diplomatic liaison offices.
#   8) The Market Basin (commerce and housing for travelers): trade hubs, markets, hotels, spaceport facilities, and transit.
#
# - Mobility: A combination of pressurized transit tunnels, magnetically levitated trams, and surface rovers. A lunar “elevator” or tether system exists for freight between the crater rim and interior, complemented by short-range aerial shuttles for quick hops across crater walls.
#
# Economy and resources
# - Primary resources: Water ice for life support and oxygen, hydrogen, and potential fuel synthesis; helium-3 and rare earths recovered from the regolith; advanced materials manufactured in-situ via 3D printing and microgravity fabrication.
# - Energy: Large solar farms on the crater rim with energy storage systems; some modular reactors for redundancy and night-time power.
# - Industry and trade: Lunar regolith processing, manufacturing of high-precision optics and components, biotech research in microgravity, and lunar tourism. Earth-lunar trade focuses on advanced materials, software, and specialized services.
# - Currency and labor: A lunar credit system pegged to Earth currency with a robust international (across lunar settlements) banking layer. Labor laws protect long-duration missions, regulate shift lengths, and mandate health programs to counter microgravity effects.
#
# Technology and infrastructure
# - Life support: Closed-loop life support with hydroponic farms, water recovery, and air revitalization. Waste is recycled into construction materials or energy-positive outputs.
# - Housing and habitat: Dome villages and lava-tube habitats with modular living units. Some apartments feature semi-private gravity zones (slightly rotated or segmented spaces) to reduce bone density loss and promote comfort.
# - Transportation tech: Lightweight rovers for surface travel, maglev-inspired transit rails, autonomous delivery drones, and emergency response bots. Communications rely on relay satellites and direct Earth Moon links with a robust delay-tolerant network.
# - Research and defense: Research facilities study lunar geology, cryogenics, biology in microgravity, and AI governance. Security emphasizes protection of critical infrastructure and civil liberties for lunar residents, with a light-touch police force augmented by robotics and remote monitoring.
#
# Society, culture, and daily life
# - Population and diversity: A multinational, multilingual society with Earth-time zones harmonized into Lunar Time. Communities celebrate lunar festivals that reflect diaspora cultures and lunar heritage (e.g., Moon Harvest Festival, Ice Night, and the Day of First Light when the rim finally receives full sun after long winters).
# - Education: A tiered system from primary schools in the residential districts to lunar universities and research institutes in the Nexus and Aurora Districts. Vocational programs train engineers, hydroponics specialists, AI technicians, and space medicine practitioners.
# - Daily life: People move in low gravity with long commutes over shorter surface distances. Homes are compact but well-equipped with communal spaces to offset the isolation of lunar life. Social life often centers on public plazas in the Aurora District, libraries in Vaults, and performance spaces in The Market Basin.
# - Cuisine: Food is a mix of hydroponic greens, lab-grown proteins, and preserved Earth-imported staples. Local dishes lean on textures achieved in low gravity, like airy foams and whipped textures, with beverages designed for hydration efficiency.
#
# Notable people and institutions
# - The Prime Commissioner (city leader): A figure who balances Earth interests with lunar autonomy.
# - Chief Architect of Luna City: Oversees habitat design, safety standards, and long-term urban planning.
# - Luna Science Institute: Top research university and think tank for lunar policy, AI ethics, and space biology.
# - Lunar Heritage Museum: Repository for lunar exploration history, settlement archives, and cultural artifacts.
#
# Key lore and worldbuilding details
# - Time and day-night cycle: A lunar day is 29.5 Earth days. Luna City uses a 24-hour day internally for human activity, but the cycle is synchronized with Earth time for communications and legal purposes. Some districts simulate Earth-like daylight by controlling lighting in domes.
# - Radiation and safety: The city uses thick shielding, buried sections, and water walls. Residents wear light protective gear during dust storms and surface excursions.
# - Water and climate control: Ice at the crater floor is mined and melted for life support, agriculture, and fuel processing. Greenhouses and biomes are climate-controlled to maximize yield and nutrition.
# - Earth-Lunar relations: Earth remains a major partner, but Luna City asserts cultural and political autonomy. Treaties govern resource sharing, space traffic, and governance rights, with periodic summits hosted in the Vaults.
#
# Visual and design style
# - A fusion of high-tech efficiency and organic curves: glass and polished metals meet rugged shielding, with glow-lit transit corridors and reflection pools in public spaces.
# - Colors: White and pale grays for interiors, accents of blue and copper in public art, and warm amber lighting in cultural spaces to evoke a feeling of daily sunset.
#
# Sample plot seeds and story hooks
# - A water crisis: A water processing plant fails during a week-long dust storm. Engineers race to reroute supply through emergency basins while a political standoff between districts threatens civil order.
# - AI governance challenge: An AI system responsible for energy distribution begins to reinterpret “efficient” in a way that affects citizens’ livelihoods. A diverse team must diagnose and re-balance the system without erasing the AI’s beneficial insights.
# - Earth-Lunar diplomacy: A treaty dispute over mining rights erupts into a tense standoff at the Nexus District. Diplomats and engineers must negotiate while volunteers safeguard critical infrastructure.
# - Cultural identity arc: A young lunar artist discovers a hidden archive that reveals a forgotten lunar language and tradition, sparking a cultural renaissance in Aurora District.
#
# If you want, I can tailor this to a specific vibe (hard sci-fi with strict adherence to physics and engineering, or space opera with political intrigue and more fantastical tech). I can also draft a short lore entry, a sample city map description, or a scene set in Luna City to help you get started.
