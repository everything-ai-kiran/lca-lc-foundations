# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# My training data goes up to June 2024. I don’t have live internet access by default, so I can’t fetch post-cutoff information unless your environment has a browsing tool enabled or you provide the new data yourself.
#
# What I can do:
# - Explain concepts, history, and general guidance based on that knowledge.
# - Help you analyze or summarize information you provide.
# - Help craft search queries or outline how to verify the latest details with current sources if you want to look them up yourself.
#
# If you need the very latest facts (news, product updates, policy changes, etc.), please share the details you have or enable/bypass browsing if that feature is available.

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

web_search.invoke("Who is the current mayor of Toronto?")
# Out:
# {'query': 'Who is the current mayor of Toronto?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://en.wikipedia.org/wiki/Mayor_of_Toronto',
#    'title': 'Mayor of Toronto - Wikipedia',
#    'content': 'Olivia Chow has served as the 66th and current mayor of Toronto since July 12, 2023, after winning the 2023 by-election.',
#    'score': 0.9997241,
#    'raw_content': None},
#   {'url': 'https://www.toronto.ca/city-government/council/office-of-the-mayor/about-mayor/',
#    'title': 'About Mayor Olivia Chow - City of Toronto',
#    'content': 'Olivia Chow is the 66th Mayor of Toronto, the first person of Asian descent to serve as Mayor, and the first woman since the six municipalities of Metro',
#    'score': 0.9990527,
#    'raw_content': None},
#   {'url': 'https://www.npr.org/2023/06/27/1184582839/olivia-chow-toronto-mayor-progressive-first-chinese-canadian',
#    'title': "Olivia Chow is elected Toronto's mayor — marking a shift in the city's ...",
#    'content': 'Olivia Chow is the new mayor-elect of Toronto, making her the first Chinese Canadian to win the office.',
#    'score': 0.9988028,
#    'raw_content': None},
#   {'url': 'https://en.wikipedia.org/wiki/Olivia_Chow',
#    'title': 'Olivia Chow - Wikipedia',
#    'content': 'Olivia Chow (born March 24, 1957) is a Canadian politician who has been the 66th and current mayor of Toronto since 2023. Previously, Chow served as the New',
#    'score': 0.9978677,
#    'raw_content': None},
#   {'url': 'https://www.mayoroliviachow.ca/about',
#    'title': 'Get to know the Mayor - Mayor Olivia Chow',
#    'content': 'Olivia Chow is the 66th Mayor of Toronto and the first woman of Asian descent elected to the office. · Born in Hong Kong, Mayor Olivia Chow immigrated to Toronto',
#    'score': 0.9959927,
#    'raw_content': None}],
#  'response_time': 0.67,
#  'request_id': 'af121100-5e04-4e50-93e2-920ab06c7a84'}

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search]
)

question = HumanMessage(content="Who is the current mayor of Toronto?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='Who is the current mayor of Toronto?', additional_kwargs={}, response_metadata={}, id='4dc2fc27-d616-4472-8d98-dc5384b4ca76'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 421, 'prompt_tokens': 132, 'total_tokens': 553, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DRNK1ryC3qigAPzlRobJM8cnMSwJs', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d5f17-a184-7e43-8875-1663c8512f70-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'current mayor of Toronto Olivia Chow took office date 2023 2024'}, 'id': 'call_xxVlkqnGWE27ucnngzJwuwIo', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 132, 'output_tokens': 421, 'total_tokens': 553, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}}),
#  ToolMessage(content='{"query": "current mayor of Toronto Olivia Chow took office date 2023 2024", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.toronto.ca/news/mayor-olivia-chow-takes-office-as-mayor-of-toronto/", "title": "Mayor Olivia Chow takes office as Mayor of Toronto", "content": "News Release July 12, 2023 Today, Mayor Olivia Chow officially assumed her role as the 66th Mayor of Toronto and fifth Mayor since", "score": 0.99984396, "raw_content": null}, {"url": "https://toronto.citynews.ca/2023/07/11/olivia-chow-toronto-mayor-priorities-2024-city-budget/", "title": "Olivia Chow officially takes office as Toronto\'s 66th mayor", "content": "Chow, a former NDP MP and past city councillor, defeated 101 other candidates to win last month\'s mayoral byelection to replace John Tory. Her", "score": 0.99981767, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=yDazz0KKihY", "title": "Olivia Chow officially takes office as mayor of Toronto - YouTube", "content": "Olivia Chow made the declaration of office as Toronto\'s 66th mayor this morning, just two weeks after winning the city\'s top job in a", "score": 0.9996594, "raw_content": null}, {"url": "https://www.cbc.ca/news/canada/toronto/olivia-chow-declaration-office-toronto-mayor-1.6904283", "title": "Olivia Chow officially takes office as Toronto\'s 66th mayor | CBC News", "content": "Olivia Chow officially took office as mayor of Toronto Wednesday, becoming the third woman and first racialized person to lead Canada\'s most populous city.", "score": 0.998103, "raw_content": null}, {"url": "https://www.npr.org/2023/06/27/1184582839/olivia-chow-toronto-mayor-progressive-first-chinese-canadian", "title": "Olivia Chow is elected Toronto\'s mayor — marking a shift in the city\'s ...", "content": "Progressive mayor-elect Olivia Chow is the first Chinese Canadian to win the office, ending more than a decade of conservative leadership.", "score": 0.99746895, "raw_content": null}], "response_time": 0.88, "request_id": "8548749b-bdc1-44bc-98bd-fe66be0da8a6"}', name='web_search', id='9a05e3c7-873a-44d8-8274-1296ed4feb71', tool_call_id='call_xxVlkqnGWE27ucnngzJwuwIo'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 491, 'prompt_tokens': 756, 'total_tokens': 1247, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DRNK6YkV2tuzur9MHu2se7nk82Qaa', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d5f17-b36a-7b50-bc35-e4554ddfda7f-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'Is Olivia Chow still the Mayor of Toronto 2024 2025 2026 current mayor of Toronto'}, 'id': 'call_BO1FbbyXd7Ur0KaMJxOklxIp', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 756, 'output_tokens': 491, 'total_tokens': 1247, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}}),
#  ToolMessage(content='{"query": "Is Olivia Chow still the Mayor of Toronto 2024 2025 2026 current mayor of Toronto", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://en.wikipedia.org/wiki/Olivia_Chow", "title": "Olivia Chow - Wikipedia", "content": "Olivia Chow (born March 24, 1957) is a Canadian politician who has been the 66th and current mayor of Toronto since 2023. Previously, Chow served as the New", "score": 0.8235701, "raw_content": null}, {"url": "https://toronto.citynews.ca/2026/01/01/toronto-mayor-olivia-chow-reflects-on-2025-looks-ahead-to-2026/", "title": "Toronto Mayor Olivia Chow reflects on 2025, looks ahead to 2026", "content": "680 NewsRadio City Hall reporter, Momin Qureshi sits down with Toronto Mayor Olivia Chow to look back on 2025, and what she hopes for", "score": 0.7300017, "raw_content": null}, {"url": "https://www.toronto.ca/city-government/council/office-of-the-mayor/about-mayor/", "title": "About Mayor Olivia Chow - City of Toronto", "content": "Olivia Chow is the 66th Mayor of Toronto, the first person of Asian descent to serve as Mayor, and the first woman since the six municipalities of Metro", "score": 0.6947383, "raw_content": null}, {"url": "https://www.mayoroliviachow.ca/about", "title": "Get to know the Mayor - Mayor Olivia Chow", "content": "Olivia Chow is the 66th Mayor of Toronto and the first woman of Asian descent elected to the office.", "score": 0.67037153, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=p_eeHqKhCAE", "title": "Olivia Chow looks ahead to Toronto\'s future in 2026 - YouTube", "content": "Toronto Mayor Olivia Chow speaks with CTV News about her year in office and what she hopes to accomplish for the city in 2026.", "score": 0.6633424, "raw_content": null}], "response_time": 0.78, "request_id": "117550c2-b126-4231-8084-9342a517636c"}', name='web_search', id='91c1123a-d9da-4fbb-a987-2599d3b54580', tool_call_id='call_BO1FbbyXd7Ur0KaMJxOklxIp'),
#  AIMessage(content='Olivia Chow is the current mayor of Toronto. She has served as the 66th mayor since July 2023.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 610, 'prompt_tokens': 1347, 'total_tokens': 1957, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DRNKBf37LaSoYsG1b8symNvfLQYSl', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d5f17-c5f2-7073-9539-68489a5fc893-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1347, 'output_tokens': 610, 'total_tokens': 1957, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}})]

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r
